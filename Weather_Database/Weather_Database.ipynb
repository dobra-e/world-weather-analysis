# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 705

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        cloudiness = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']
        currentdesc = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({'City':city.title(),
                         'Lat':lat,
                         'Lng':lng,
                         'Max Temp':max_temp,
                         'Humidity':humidity,
                         'Cloudiness':cloudiness,
                         'Wind Speed':wind,
                         'Country':country,
                         'Current Description':currentdesc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | chegdomyn
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | tarabha
# Processing Record 8 of Set 1 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 9 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 1 | pangnirtung
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | mount gambier
# Processing Record 18 of Set 1 | namibe
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | hambantota
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | wattegama
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | miranda
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | grand island
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | muli
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | gushikawa
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | zonguldak
# Processing Record 44 of Set 1 | mercedes
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | honiara
# Processing Record 47 of Set 1 | tagusao
# Processing Record 48 of Set 1 | garowe
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | taywarah
# Processing Record 2 of Set 2 | quatre cocos
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | matara
# Processing Record 5 of Set 2 | yar-sale
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | ternate
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | ambon
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | paveh
# Processing Record 15 of Set 2 | sept-iles
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | asau
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | bridgeport
# Processing Record 22 of Set 2 | sola
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | comodoro rivadavia
# Processing Record 25 of Set 2 | sinnamary
# Processing Record 26 of Set 2 | rancho palos verdes
# Processing Record 27 of Set 2 | sao jose da coroa grande
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | quelimane
# Processing Record 32 of Set 2 | gobabis
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | vestmannaeyjar
# Processing Record 35 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | tura
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | moron
# Processing Record 47 of Set 2 | kupang
# Processing Record 48 of Set 2 | gunjur
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | demidov
# Processing Record 1 of Set 3 | yermakovskoye
# Processing Record 2 of Set 3 | isangel
# Processing Record 3 of Set 3 | plaeng yao
# Processing Record 4 of Set 3 | wicklow
# Processing Record 5 of Set 3 | tarko-sale
# Processing Record 6 of Set 3 | mecca
# Processing Record 7 of Set 3 | la ronge
# Processing Record 8 of Set 3 | gurjaani
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | guerrero negro
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | sao gabriel
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | bandarbeyla
# Processing Record 20 of Set 3 | laguna
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | krasnyy chikoy
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | carahue
# Processing Record 26 of Set 3 | khuzdar
# Processing Record 27 of Set 3 | rognan
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | bhandara
# Processing Record 30 of Set 3 | fairbanks
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | calama
# Processing Record 33 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | kawalu
# Processing Record 38 of Set 3 | nome
# Processing Record 39 of Set 3 | marawi
# Processing Record 40 of Set 3 | tambun
# Processing Record 41 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 3 | talas
# Processing Record 43 of Set 3 | wajima
# Processing Record 44 of Set 3 | feijo
# Processing Record 45 of Set 3 | dubovka
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | burica
# City not found. Skipping...
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | calvinia
# Processing Record 1 of Set 4 | dongning
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | mahajanga
# Processing Record 5 of Set 4 | marienburg
# Processing Record 6 of Set 4 | olinda
# Processing Record 7 of Set 4 | lagos
# Processing Record 8 of Set 4 | ballina
# Processing Record 9 of Set 4 | villaviciosa
# Processing Record 10 of Set 4 | bredasdorp
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | cape town
# Processing Record 13 of Set 4 | amahai
# Processing Record 14 of Set 4 | tsagan aman
# Processing Record 15 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 16 of Set 4 | avon lake
# Processing Record 17 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | bethel
# Processing Record 20 of Set 4 | londonderry
# Processing Record 21 of Set 4 | soyo
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | atar
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | rio grande
# Processing Record 27 of Set 4 | makakilo city
# Processing Record 28 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 4 | ndjole
# Processing Record 30 of Set 4 | aginskoye
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | russell
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | meybod
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | eureka
# Processing Record 38 of Set 4 | marsh harbour
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | creel
# Processing Record 41 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 4 | manicore
# Processing Record 43 of Set 4 | mogadishu
# Processing Record 44 of Set 4 | west lafayette
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | high rock
# Processing Record 47 of Set 4 | capao da canoa
# Processing Record 48 of Set 4 | luebo
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 5 | hay river
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | ayagoz
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | sarramea
# Processing Record 7 of Set 5 | aswan
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | balkanabat
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | dossor
# Processing Record 12 of Set 5 | sakakah
# Processing Record 13 of Set 5 | spetsai
# City not found. Skipping...
# Processing Record 14 of Set 5 | kungurtug
# Processing Record 15 of Set 5 | goya
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | looc
# Processing Record 19 of Set 5 | neiafu
# Processing Record 20 of Set 5 | hofn
# Processing Record 21 of Set 5 | roma
# Processing Record 22 of Set 5 | santo domingo
# Processing Record 23 of Set 5 | hirtshals
# Processing Record 24 of Set 5 | yarmouth
# Processing Record 25 of Set 5 | banda aceh
# Processing Record 26 of Set 5 | sahiwal
# Processing Record 27 of Set 5 | bodden town
# Processing Record 28 of Set 5 | kestel
# Processing Record 29 of Set 5 | barrow
# Processing Record 30 of Set 5 | aljojuca
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | skjervoy
# Processing Record 33 of Set 5 | mayumba
# Processing Record 34 of Set 5 | toba
# Processing Record 35 of Set 5 | kasongo-lunda
# Processing Record 36 of Set 5 | pemba
# Processing Record 37 of Set 5 | saint-joseph
# Processing Record 38 of Set 5 | severnoye
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | bafoulabe
# Processing Record 41 of Set 5 | biak
# Processing Record 42 of Set 5 | praya
# Processing Record 43 of Set 5 | alice springs
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | cap malheureux
# Processing Record 46 of Set 5 | florianopolis
# Processing Record 47 of Set 5 | bikaner
# Processing Record 48 of Set 5 | batagay-alyta
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | victoria
# Processing Record 1 of Set 6 | tokur
# Processing Record 2 of Set 6 | rio claro
# Processing Record 3 of Set 6 | ilinskiy
# Processing Record 4 of Set 6 | pangoa
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | outlook
# Processing Record 9 of Set 6 | kaitangata
# Processing Record 10 of Set 6 | east london
# Processing Record 11 of Set 6 | tezpur
# Processing Record 12 of Set 6 | the valley
# Processing Record 13 of Set 6 | lucea
# Processing Record 14 of Set 6 | troitskoye
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | oranjemund
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | senno
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | raymond
# Processing Record 21 of Set 6 | flinders
# Processing Record 22 of Set 6 | safford
# Processing Record 23 of Set 6 | ponta delgada
# Processing Record 24 of Set 6 | maimon
# City not found. Skipping...
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | taman
# Processing Record 27 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 6 | suntar
# Processing Record 29 of Set 6 | aliwal north
# Processing Record 30 of Set 6 | cao bang
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | severobaykalsk
# Processing Record 33 of Set 6 | caxito
# Processing Record 34 of Set 6 | kahului
# Processing Record 35 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 6 | upernavik
# Processing Record 37 of Set 6 | ostrovnoy
# Processing Record 38 of Set 6 | timmins
# Processing Record 39 of Set 6 | inirida
# Processing Record 40 of Set 6 | kushmurun
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | nizhneudinsk
# Processing Record 43 of Set 6 | linxia
# Processing Record 44 of Set 6 | vila velha
# Processing Record 45 of Set 6 | goderich
# Processing Record 46 of Set 6 | kichera
# Processing Record 47 of Set 6 | berlevag
# Processing Record 48 of Set 6 | carutapera
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | chimbote
# Processing Record 1 of Set 7 | marsa matruh
# Processing Record 2 of Set 7 | hadejia
# Processing Record 3 of Set 7 | bella union
# Processing Record 4 of Set 7 | fayetteville
# Processing Record 5 of Set 7 | cortez
# Processing Record 6 of Set 7 | sault sainte marie
# Processing Record 7 of Set 7 | dunedin
# Processing Record 8 of Set 7 | prince rupert
# Processing Record 9 of Set 7 | kolpashevo
# Processing Record 10 of Set 7 | dicabisagan
# Processing Record 11 of Set 7 | sao felix do xingu
# Processing Record 12 of Set 7 | batagay
# Processing Record 13 of Set 7 | pocone
# Processing Record 14 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 7 | port-gentil
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | morehead
# Processing Record 18 of Set 7 | xam nua
# Processing Record 19 of Set 7 | nanortalik
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | oyama
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | norman wells
# Processing Record 24 of Set 7 | hearst
# Processing Record 25 of Set 7 | zhanakorgan
# Processing Record 26 of Set 7 | shingu
# Processing Record 27 of Set 7 | portree
# Processing Record 28 of Set 7 | clarence town
# Processing Record 29 of Set 7 | auki
# Processing Record 30 of Set 7 | beringovskiy
# Processing Record 31 of Set 7 | denpasar
# Processing Record 32 of Set 7 | airai
# Processing Record 33 of Set 7 | khipro
# Processing Record 34 of Set 7 | fukuma
# Processing Record 35 of Set 7 | nouakchott
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | evensk
# Processing Record 38 of Set 7 | hualmay
# Processing Record 39 of Set 7 | galle
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | teya
# Processing Record 43 of Set 7 | nador
# Processing Record 44 of Set 7 | orodara
# Processing Record 45 of Set 7 | bambous virieux
# Processing Record 46 of Set 7 | nizhniy tsasuchey
# Processing Record 47 of Set 7 | bridlington
# Processing Record 48 of Set 7 | port augusta
# Processing Record 49 of Set 7 | summerville
# Processing Record 50 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 8 | cusco
# Processing Record 2 of Set 8 | barreiras
# Processing Record 3 of Set 8 | roald
# Processing Record 4 of Set 8 | cabo san lucas
# Processing Record 5 of Set 8 | sorland
# Processing Record 6 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 7 of Set 8 | kinablangan
# Processing Record 8 of Set 8 | ortakoy
# Processing Record 9 of Set 8 | pampierstad
# Processing Record 10 of Set 8 | juneau
# Processing Record 11 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | santa isabel do rio negro
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | pizhanka
# Processing Record 16 of Set 8 | fonte boa
# Processing Record 17 of Set 8 | omsukchan
# Processing Record 18 of Set 8 | dhidhdhoo
# Processing Record 19 of Set 8 | tabou
# Processing Record 20 of Set 8 | sisimiut
# Processing Record 21 of Set 8 | ahipara
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | gasa
# Processing Record 24 of Set 8 | alanya
# Processing Record 25 of Set 8 | sambava
# Processing Record 26 of Set 8 | salisbury
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | san andres
# Processing Record 29 of Set 8 | barcelos
# Processing Record 30 of Set 8 | kendari
# Processing Record 31 of Set 8 | mulege
# Processing Record 32 of Set 8 | vanimo
# Processing Record 33 of Set 8 | fanai
# Processing Record 34 of Set 8 | chowchilla
# Processing Record 35 of Set 8 | yining
# Processing Record 36 of Set 8 | seydi
# Processing Record 37 of Set 8 | manokwari
# Processing Record 38 of Set 8 | abu dhabi
# Processing Record 39 of Set 8 | kralendijk
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | ninotsminda
# Processing Record 42 of Set 8 | wonthaggi
# Processing Record 43 of Set 8 | lubango
# Processing Record 44 of Set 8 | funadhoo
# Processing Record 45 of Set 8 | mantenopolis
# Processing Record 46 of Set 8 | pak phanang
# Processing Record 47 of Set 8 | chimore
# Processing Record 48 of Set 8 | guamal
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | yellamanchili
# City not found. Skipping...
# Processing Record 1 of Set 9 | misratah
# Processing Record 2 of Set 9 | lazaro cardenas
# Processing Record 3 of Set 9 | bud
# Processing Record 4 of Set 9 | coihaique
# Processing Record 5 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 9 | sumbe
# Processing Record 7 of Set 9 | oistins
# Processing Record 8 of Set 9 | yenagoa
# Processing Record 9 of Set 9 | tezu
# Processing Record 10 of Set 9 | acari
# Processing Record 11 of Set 9 | portland
# Processing Record 12 of Set 9 | butterworth
# Processing Record 13 of Set 9 | broken hill
# Processing Record 14 of Set 9 | saint-paul
# Processing Record 15 of Set 9 | rocha
# Processing Record 16 of Set 9 | belyy yar
# Processing Record 17 of Set 9 | jalpan
# Processing Record 18 of Set 9 | monte carmelo
# Processing Record 19 of Set 9 | baykit
# Processing Record 20 of Set 9 | boyolangu
# Processing Record 21 of Set 9 | adjumani
# Processing Record 22 of Set 9 | grand gaube
# Processing Record 23 of Set 9 | bima
# Processing Record 24 of Set 9 | bodh gaya
# Processing Record 25 of Set 9 | mildura
# Processing Record 26 of Set 9 | tefe
# Processing Record 27 of Set 9 | krasnousolskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | anshun
# Processing Record 29 of Set 9 | tres de maio
# Processing Record 30 of Set 9 | hokitika
# Processing Record 31 of Set 9 | khandyga
# Processing Record 32 of Set 9 | hanyang
# Processing Record 33 of Set 9 | narsaq
# Processing Record 34 of Set 9 | abu samrah
# Processing Record 35 of Set 9 | boa esperanca
# Processing Record 36 of Set 9 | ouesso
# Processing Record 37 of Set 9 | koyilandi
# City not found. Skipping...
# Processing Record 38 of Set 9 | rudbar
# Processing Record 39 of Set 9 | tadine
# Processing Record 40 of Set 9 | keti bandar
# Processing Record 41 of Set 9 | sistranda
# Processing Record 42 of Set 9 | tawau
# Processing Record 43 of Set 9 | eyl
# Processing Record 44 of Set 9 | cody
# Processing Record 45 of Set 9 | semnan
# Processing Record 46 of Set 9 | kalmunai
# Processing Record 47 of Set 9 | nizhnevartovsk
# Processing Record 48 of Set 9 | deputatskiy
# Processing Record 49 of Set 9 | liverpool
# Processing Record 50 of Set 9 | dingle
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | santiago
# Processing Record 3 of Set 10 | santa maria
# Processing Record 4 of Set 10 | pelym
# Processing Record 5 of Set 10 | meppel
# Processing Record 6 of Set 10 | vila franca do campo
# Processing Record 7 of Set 10 | pisco
# Processing Record 8 of Set 10 | pacific grove
# Processing Record 9 of Set 10 | kibre mengist
# Processing Record 10 of Set 10 | khor
# Processing Record 11 of Set 10 | aktash
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 13 of Set 10 | virginia beach
# Processing Record 14 of Set 10 | moerai
# Processing Record 15 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 16 of Set 10 | vardo
# Processing Record 17 of Set 10 | sidi ali
# Processing Record 18 of Set 10 | geraldton
# Processing Record 19 of Set 10 | riohacha
# Processing Record 20 of Set 10 | torbat-e jam
# Processing Record 21 of Set 10 | bay roberts
# Processing Record 22 of Set 10 | kijang
# Processing Record 23 of Set 10 | livermore
# Processing Record 24 of Set 10 | vilnius
# Processing Record 25 of Set 10 | kloulklubed
# Processing Record 26 of Set 10 | sandomierz
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | itoman
# Processing Record 29 of Set 10 | road town
# Processing Record 30 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 10 | nuevo progreso
# Processing Record 32 of Set 10 | ninghai
# Processing Record 33 of Set 10 | kampot
# Processing Record 34 of Set 10 | havelock
# Processing Record 35 of Set 10 | garcia
# Processing Record 36 of Set 10 | kokkarion
# Processing Record 37 of Set 10 | lovozero
# Processing Record 38 of Set 10 | ouegoa
# Processing Record 39 of Set 10 | winkler
# Processing Record 40 of Set 10 | san cristobal
# Processing Record 41 of Set 10 | guasdualito
# Processing Record 42 of Set 10 | sarkand
# Processing Record 43 of Set 10 | tulu bolo
# Processing Record 44 of Set 10 | esperance
# Processing Record 45 of Set 10 | vrangel
# Processing Record 46 of Set 10 | bonthe
# Processing Record 47 of Set 10 | la libertad
# Processing Record 48 of Set 10 | tevriz
# Processing Record 49 of Set 10 | port blair
# Processing Record 50 of Set 10 | kysyl-syr
# Processing Record 1 of Set 11 | port hueneme
# Processing Record 2 of Set 11 | karpuninskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | yuanping
# Processing Record 4 of Set 11 | aksarka
# Processing Record 5 of Set 11 | angren
# Processing Record 6 of Set 11 | erenhot
# Processing Record 7 of Set 11 | apac
# Processing Record 8 of Set 11 | miquelon
# Processing Record 9 of Set 11 | necochea
# Processing Record 10 of Set 11 | aranda de duero
# Processing Record 11 of Set 11 | vulcan
# Processing Record 12 of Set 11 | villa maria
# Processing Record 13 of Set 11 | aripuana
# Processing Record 14 of Set 11 | cerqueira cesar
# Processing Record 15 of Set 11 | kuzino
# Processing Record 16 of Set 11 | pandan
# Processing Record 17 of Set 11 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 18 of Set 11 | vaitape
# Processing Record 19 of Set 11 | pineville
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | luz
# Processing Record 23 of Set 11 | hornepayne
# Processing Record 24 of Set 11 | santa cruz del norte
# Processing Record 25 of Set 11 | bulancak
# Processing Record 26 of Set 11 | abha
# Processing Record 27 of Set 11 | coffs harbour
# Processing Record 28 of Set 11 | cottonwood
# Processing Record 29 of Set 11 | solvychegodsk
# Processing Record 30 of Set 11 | warrnambool
# Processing Record 31 of Set 11 | pimentel
# Processing Record 32 of Set 11 | durazno
# Processing Record 33 of Set 11 | jerusalem
# Processing Record 34 of Set 11 | tessalit
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | tautira
# Processing Record 37 of Set 11 | moravsky beroun
# Processing Record 38 of Set 11 | berdigestyakh
# Processing Record 39 of Set 11 | manitouwadge
# Processing Record 40 of Set 11 | panaba
# Processing Record 41 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 11 | coalinga
# Processing Record 43 of Set 11 | henties bay
# Processing Record 44 of Set 11 | molchanovo
# Processing Record 45 of Set 11 | vila do maio
# Processing Record 46 of Set 11 | polunochnoye
# Processing Record 47 of Set 11 | kaniama
# Processing Record 48 of Set 11 | ormara
# Processing Record 49 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 11 | jiwani
# Processing Record 1 of Set 12 | magadan
# Processing Record 2 of Set 12 | tiarei
# Processing Record 3 of Set 12 | leh
# Processing Record 4 of Set 12 | namatanai
# Processing Record 5 of Set 12 | nago
# Processing Record 6 of Set 12 | kon tum
# Processing Record 7 of Set 12 | caala
# Processing Record 8 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 9 of Set 12 | andenes
# Processing Record 10 of Set 12 | camacha
# Processing Record 11 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | bilma
# Processing Record 13 of Set 12 | galesong
# Processing Record 14 of Set 12 | changde
# Processing Record 15 of Set 12 | banon
# Processing Record 16 of Set 12 | north myrtle beach
# Processing Record 17 of Set 12 | husavik
# Processing Record 18 of Set 12 | dali
# Processing Record 19 of Set 12 | buraydah
# Processing Record 20 of Set 12 | wageningen
# Processing Record 21 of Set 12 | goure
# Processing Record 22 of Set 12 | san-pedro
# Processing Record 23 of Set 12 | morondava
# Processing Record 24 of Set 12 | moindou
# Processing Record 25 of Set 12 | arlit
# Processing Record 26 of Set 12 | whitehorse
# Processing Record 27 of Set 12 | yumen
# Processing Record 28 of Set 12 | san pedro
# Processing Record 29 of Set 12 | harper
# Processing Record 30 of Set 12 | marathon
# Processing Record 31 of Set 12 | savalou
# Processing Record 32 of Set 12 | fort nelson
# Processing Record 33 of Set 12 | drochia
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | cerro punta
# Processing Record 36 of Set 12 | ust-ilimsk
# Processing Record 37 of Set 12 | voznesenye
# Processing Record 38 of Set 12 | dalby
# Processing Record 39 of Set 12 | charyshskoye
# Processing Record 40 of Set 12 | cicuco
# Processing Record 41 of Set 12 | okha
# Processing Record 42 of Set 12 | acapulco
# Processing Record 43 of Set 12 | rawah
# Processing Record 44 of Set 12 | halifax
# Processing Record 45 of Set 12 | saint-louis
# Processing Record 46 of Set 12 | blairmore
# Processing Record 47 of Set 12 | roebourne
# Processing Record 48 of Set 12 | martapura
# Processing Record 49 of Set 12 | bathsheba
# Processing Record 50 of Set 12 | san juan
# Processing Record 1 of Set 13 | tornio
# Processing Record 2 of Set 13 | tual
# Processing Record 3 of Set 13 | burgeo
# Processing Record 4 of Set 13 | mitsamiouli
# Processing Record 5 of Set 13 | hamilton
# Processing Record 6 of Set 13 | avanigadda
# Processing Record 7 of Set 13 | pine bluff
# Processing Record 8 of Set 13 | victor harbor
# Processing Record 9 of Set 13 | mantua
# Processing Record 10 of Set 13 | vao
# Processing Record 11 of Set 13 | urengoy
# Processing Record 12 of Set 13 | quesnel
# Processing Record 13 of Set 13 | cururupu
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | port jervis
# Processing Record 16 of Set 13 | alexandria
# Processing Record 17 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 18 of Set 13 | kiknur
# Processing Record 19 of Set 13 | pitimbu
# Processing Record 20 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 13 | sunamganj
# City not found. Skipping...
# Processing Record 22 of Set 13 | havoysund
# Processing Record 23 of Set 13 | krasnoselkup
# Processing Record 24 of Set 13 | codigoro
# Processing Record 25 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 13 | praia da vitoria
# Processing Record 27 of Set 13 | zhuhai
# Processing Record 28 of Set 13 | brewster
# Processing Record 29 of Set 13 | santa cruz
# Processing Record 30 of Set 13 | novikovo
# Processing Record 31 of Set 13 | puerto escondido
# Processing Record 32 of Set 13 | jumla
# Processing Record 33 of Set 13 | tarakan
# Processing Record 34 of Set 13 | blytheville
# Processing Record 35 of Set 13 | gucheng
# Processing Record 36 of Set 13 | ust-tsilma
# Processing Record 37 of Set 13 | riverton
# Processing Record 38 of Set 13 | ajdabiya
# Processing Record 39 of Set 13 | westminster
# Processing Record 40 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 41 of Set 13 | port keats
# Processing Record 42 of Set 13 | bac lieu
# Processing Record 43 of Set 13 | kodinsk
# Processing Record 44 of Set 13 | turukhansk
# Processing Record 45 of Set 13 | gorkovskiy
# Processing Record 46 of Set 13 | lakes entrance
# Processing Record 47 of Set 13 | shenjiamen
# Processing Record 48 of Set 13 | samarai
# Processing Record 49 of Set 13 | suez
# Processing Record 50 of Set 13 | turkistan
# Processing Record 1 of Set 14 | nyurba
# Processing Record 2 of Set 14 | ambilobe
# Processing Record 3 of Set 14 | gunnedah
# Processing Record 4 of Set 14 | abu kamal
# Processing Record 5 of Set 14 | maralal
# Processing Record 6 of Set 14 | muros
# Processing Record 7 of Set 14 | mandalgovi
# Processing Record 8 of Set 14 | shebekino
# Processing Record 9 of Set 14 | vestmanna
# Processing Record 10 of Set 14 | shakawe
# Processing Record 11 of Set 14 | maceio
# Processing Record 12 of Set 14 | viedma
# Processing Record 13 of Set 14 | catamarca
# Processing Record 14 of Set 14 | prescott
# Processing Record 15 of Set 14 | shimoda
# Processing Record 16 of Set 14 | kishtwar
# Processing Record 17 of Set 14 | lensk
# Processing Record 18 of Set 14 | remontnoye
# Processing Record 19 of Set 14 | micheweni
# Processing Record 20 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | broome
# Processing Record 22 of Set 14 | salvador
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 14 | iquique
# Processing Record 26 of Set 14 | coahuayana
# Processing Record 27 of Set 14 | campos altos
# Processing Record 28 of Set 14 | teguise
# Processing Record 29 of Set 14 | makat
# Processing Record 30 of Set 14 | gizo
# Processing Record 31 of Set 14 | newcastle
# Processing Record 32 of Set 14 | siyabuswa
# Processing Record 33 of Set 14 | ketchikan
# Processing Record 34 of Set 14 | coromandel
# Processing Record 35 of Set 14 | rio gallegos
# Processing Record 36 of Set 14 | xining
# Processing Record 37 of Set 14 | aneho
# Processing Record 38 of Set 14 | gerede
# Processing Record 39 of Set 14 | nauen
# Processing Record 40 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 14 | urumqi
# Processing Record 42 of Set 14 | bilibino
# Processing Record 43 of Set 14 | aquiraz
# Processing Record 44 of Set 14 | dembi dolo
# Processing Record 45 of Set 14 | bukachacha
# Processing Record 46 of Set 14 | partyzany
# Processing Record 47 of Set 14 | solnechnyy
# Processing Record 48 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 14 | awjilah
# Processing Record 50 of Set 14 | nuevitas
# Processing Record 1 of Set 15 | foumbot
# Processing Record 2 of Set 15 | mindelo
# Processing Record 3 of Set 15 | morros
# Processing Record 4 of Set 15 | teguldet
# Processing Record 5 of Set 15 | camargo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 647

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lebu -37.6167  -73.6500     59.85        58           2
# 1          Chuy -33.6971  -53.4616     80.29        51          94
# 2       Rikitea -23.1203 -134.9692     77.29        73         100
# 3     Chegdomyn  51.1167  133.0167     -0.81        96          88
# 4   New Norfolk -42.7826  147.0587     58.71        69         100
# 5       Tarabha  20.7333   83.6500     62.83        43           1
# 6     Grindavik  63.8424  -22.4338     21.67        79          75
# 7       Ushuaia -54.8000  -68.3000     49.66        50          75
# 8  Punta Arenas -53.1500  -70.9167     55.51        38          40
# 9   Pangnirtung  66.1451  -65.7125      3.20        60          75
#
#    Wind Speed Country Current Description
# 0       25.77      CL           clear sky
# 1       14.45      UY     overcast clouds
# 2       11.74      PF     overcast clouds
# 3        2.59      RU     overcast clouds
# 4        3.00      AU     overcast clouds
# 5        2.82      IN           clear sky
# 6        6.91      IS       broken clouds
# 7       21.85      AR       broken clouds
# 8       27.63      CL    scattered clouds
# 9        3.44      CA       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columnOrder = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columnOrder]

# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lebu      CL -37.6167  -73.6500     59.85        58           2
# 1           Chuy      UY -33.6971  -53.4616     80.29        51          94
# 2        Rikitea      PF -23.1203 -134.9692     77.29        73         100
# 3      Chegdomyn      RU  51.1167  133.0167     -0.81        96          88
# 4    New Norfolk      AU -42.7826  147.0587     58.71        69         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 642      Foumbot      CM   5.5079   10.6356     71.58        47          57
# 643      Mindelo      CV  16.8901  -24.9804     78.35        61          20
# 644       Morros      BR  -9.4467  -46.3003     78.85        70          97
# 645     Teguldet      RU  57.3064   88.1667     -3.84        91         100
# 646      Camargo      MX  27.6667 -105.1667     57.18        28           0
#
#      Wind Speed Current Description
# 0         25.77           clear sky
# 1         14.45     overcast clouds
# 2         11.74     overcast clouds
# 3          2.59     overcast clouds
# 4          3.00     overcast clouds
# ..          ...                 ...
# 642        2.42       broken clouds
# 643       20.71          few clouds
# 644        5.88     overcast clouds
# 645        8.30     overcast clouds
# 646        8.66           clear sky
#
# [647 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label = "City_ID")
